# %% [markdown]
# # ECE 57000: Assignment Uploader
#
# Note:
# The file helps generate html version of your ipynb file.

# %% [markdown]
# # Mount your drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Change the `your_ipynb_file_dir` to the exact path of your jupyter notebook.

# %%
def preprocess(dir):
    # To deal with the error when there is [] in the path
    dir.replace('[','[[]')
    dir.replace(']','[]]')
    return dir

########################        YOUR CODE        ##########################
your_ipynb_file_dir = '/content/drive/MyDrive/ECE57000_AI/Assignment_05/Assignment_05_Exercise.ipynb' # Example: '/content/drive/MyDrive/ECE570/Assignment_5.ipynb'

########################      END YOUR CODE      ##########################

# !jupyter nbconvert --to html '{preprocess(your_ipynb_file_dir)}'

### Please run the code below if you encounter a bug, and you are working on the same file cross-platform.

# !jupyter nbconvert --ExecutePreprocessor.store_widget_state=False --to html '{preprocess(your_ipynb_file_dir)}'

### Descriptions:
### Jupyter Notebooks store widget state information in the file metadata by default,
### and this can raise an error when attempting to work on the same file cross-platform.
### document: https://nbconvert.readthedocs.io/en/latest/execute_api.html
# Out:
# [NbConvertApp] Converting notebook /content/drive/MyDrive/ECE57000_AI/Assignment_05/Assignment_05_Exercise.ipynb to html
# [NbConvertApp] WARNING | Alternative text is missing on 11 image(s).
# [NbConvertApp] Writing 1238920 bytes to /content/drive/MyDrive/ECE57000_AI/Assignment_05/Assignment_05_Exercise.html

# %% [markdown]
# # There should be a html file generated in the same directory as your ipynb notebook. Download and then open that html file using Chrome and select Print and save as pdf.
